# %%
import requests
from io import StringIO
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
data = requests.get("https://raw.githubusercontent.com/allisol1/UMBC-CMSC631-Team6/refs/heads/main/ACS_5YR_Housing_Estimate_Data_by_County_2352642343660635057.csv")
housing_data = pd.read_csv(StringIO(data.text))
data = requests.get("https://raw.githubusercontent.com/allisol1/UMBC-CMSC636-Team6/refs/heads/main/DD_ACS_5-Year_Housing_Estimate_Data_by_County.csv")
housing_keys = pd.read_csv(StringIO(data.text))
housing_data
# Out:
#       OBJECTID_1  GEOID  STATE STUSAB    STATE_NAME  COUNTY  \
# 0              1   2063      2     AK        Alaska      63
# 1              2   2066      2     AK        Alaska      66
# 2              3   2068      2     AK        Alaska      68
# 3              4   2070      2     AK        Alaska      70
# 4              5   2090      2     AK        Alaska      90
# ...          ...    ...    ...    ...           ...     ...
# 3216        3217  46057     46     SD  South Dakota      57
# 3217        3218  46059     46     SD  South Dakota      59
# 3218        3219  46061     46     SD  South Dakota      61
# 3219        3220  46063     46     SD  South Dakota      63
# 3220        3221  46065     46     SD  South Dakota      65
#
#                       NAME  B25002EST1  B25002EST2  B25002EST2_PCT  ...  \
# 0                  Chugach        3287        2310           70.28  ...
# 1             Copper River        2902        1063           36.63  ...
# 2                   Denali        1664         726           43.63  ...
# 3               Dillingham        2462        1430           58.08  ...
# 4     Fairbanks North Star       44270       36199           81.77  ...
# ...                    ...         ...         ...             ...  ...
# 3216                Hamlin        2920        2242           76.78  ...
# 3217                  Hand        1795        1426           79.44  ...
# 3218                Hanson        1210        1039           85.87  ...
# 3219               Harding         711         516           72.57  ...
# 3220                Hughes        8041        7475           92.96  ...
#
#       B25123EST10  B25123EST10_PCT  B25123EST11  B25123EST11_PCT  B25123EST12  \
# 0              45             7.26            1             0.16            0
# 1              11             4.30            6             2.34            0
# 2              22            17.74            0             0.00            7
# 3              51             9.01            8             1.41            0
# 4             845             5.68          528             3.55           16
# ...           ...              ...          ...              ...          ...
# 3216           10             2.26            1             0.23            0
# 3217            3             0.67            0             0.00            0
# 3218            0             0.00            0             0.00            0
# 3219            0             0.00            0             0.00            0
# 3220            0             0.00            0             0.00            0
#
#       B25123EST12_PCT  B25123EST13  B25123EST13_PCT   Shape__Area  \
# 0                0.00          362            58.39  1.048120e+11
# 1                0.00          166            64.84  2.925218e+11
# 2                5.65           40            32.26  1.661374e+11
# 3                0.00          287            50.71  1.934547e+11
# 4                0.11         7401            49.72  1.058398e+11
# ...               ...          ...              ...           ...
# 3216             0.00          364            82.17  2.756067e+09
# 3217             0.00          387            86.00  7.345406e+09
# 3218             0.00          102            80.31  2.156168e+09
# 3219             0.00          170            95.51  1.415803e+10
# 3220             0.00         1366            62.12  4.061792e+09
#
#       Shape__Length
# 0      1.135352e+07
# 1      3.013518e+06
# 2      2.084188e+06
# 3      3.421842e+06
# 4      1.883222e+06
# ...             ...
# 3216   2.166601e+05
# 3217   3.554394e+05
# 3218   1.876999e+05
# 3219   4.781780e+05
# 3220   3.425127e+05
#
# [3221 rows x 245 columns]

# %%
housing_data_md = housing_data.loc[housing_data['STATE_NAME'] == "Maryland",  ['NAME','B25002EST1', 'B25002EST2']]
housing_data_md
# Out:
#                  NAME  B25002EST1  B25002EST2
# 918           Calvert       35421       32558
# 919          Caroline       13645       12160
# 920           Carroll       63767       61261
# 921             Cecil       42690       37293
# 922           Charles       61226       57388
# 923        Dorchester       16754       13433
# 924         Frederick       99179       94299
# 1044          Garrett       19428       12745
# 1045          Harford      100952       95094
# 1046           Howard      120834      116457
# 1069             Kent       10687        8274
# 1070       Montgomery      390475      372825
# 1071  Prince George's      334407      315634
# 1072     Queen Anne's       21363       19000
# 1073       St. Mary's       45867       41280
# 1074         Somerset       11476        8509
# 1197           Talbot       20252       16810
# 1198       Washington       61621       56367
# 1199         Wicomico       42452       38142
# 1200        Worcester       56485       22661
# 1224        Baltimore      293936      242499
# 1253         Allegany       32823       27369
# 1375     Anne Arundel      226330      213122
# 1376        Baltimore      337580      315347

# %%
plt.title("Percentage of Occupied to total housing units in Maryland")
plt.barh(housing_data_md['NAME'],housing_data_md['B25002EST2']/housing_data_md['B25002EST1'])
plt.ylabel("County Name")
plt.xlabel("Occupied Percentage")
plt.show()
